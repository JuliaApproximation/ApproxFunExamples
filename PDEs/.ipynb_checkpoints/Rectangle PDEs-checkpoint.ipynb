# %%
using Plots, ApproxFun, LinearAlgebra
import Domains: ×
gr();  # also works in gr;

# %% [markdown]
# # Laplace Equation $u_{xx} + u_{yy} = 0$, $u|_{\partial d} = \Re(e^{x+i y})$

# %%
d = (-1.0 .. 1.0)^2
g = Fun((x,y) -> real(exp(x+im*y)), ∂(d))  # boundary data
Δ = Laplacian(d)
u = [Dirichlet(d); Δ] \ [g; 0]

plot(u)

# %% [markdown]
# We solve with neumann on one edge
# `ldirichlet/rdirichlet/lneumann/rneumann` commands specify left/right dirichet/neumann boundary conditions

# %%
dx =dy = -1.0 .. 1.0
d = dx × dy

x,y = Fun(∂(d))
x,y = components(x),components(y)

g = [-exp(x[1])*sin(-1); exp(1)*cos(y[2]);
      exp(x[3])*cos(1);  exp(-1)*cos(y[4])]


Δ = Laplacian(d)

B = [I⊗lneumann(dy); rneumann(dx)⊗I; I⊗rdirichlet(dy); ldirichlet(dx)⊗I]
u = \([B;Δ], [g;0]; tolerance=1E-10)

plot(u)

# %% [markdown]
# # Poisson equation $u_{xx} + u_{yy} = f(x,y)$

# %%
f = Fun((x,y) -> exp(-10(x+0.2)^2-20(y-0.1)^2))  #default is (-1..1)^2
d = domain(f)
Δ = Laplacian(d)
u = [Dirichlet(d); Δ] \ [0; f]
plot(u)

# %% [markdown]
# # Helmholtz $u_{xx} + u_{yy} + 100u=0, u|_{\partial d}=1$

# %%
d = (-1.0..1.0)^2

Δ = Laplacian(d)

@time u = \([Dirichlet(d);Δ+100I], [ones(∂(d));0]; tolerance=1E-5)
plot(u)
# Out:
#  11.201322 seconds (38.70 M allocations: 1.878 GiB, 8.44% gc time)

# %%
d = (-1.0 .. 1.0)^2

Δ = Laplacian(d)

@time u = [Neumann(d); Δ+100I] \ [[[1,1],[1,1]],0]
plot(u)
# Out:
#  10.758063 seconds (29.11 M allocations: 1.600 GiB, 7.53% gc time)

# %% [markdown]
# # Screened Poisson  $u_{xx} + u_{yy} - 100u = 0, \partial u(\partial d) = 1$

# %%
d = (-1.0 .. 1.0)^2
Δ = Laplacian(d)

@time u = [Neumann(d); Δ-100.0I] \ [[[1,1],[1,1]],0.0]
plot(u)
# Out:
#   3.234590 seconds (11.04 M allocations: 659.290 MiB, 14.82% gc time)

# %% [markdown]
# # Convection $u_t + u_x = 0,u(x,0)=e^{-20x^2}, u(-1,t) = 0$

# %%
dx = -1.0 .. 1.0; dt = 0.0 .. 2.0
d = dx × dt
Dx = Derivative(d,[1,0]); Dt = Derivative(d,[0,1])
u0 = Fun(x->exp(-20x^2),dx)
@time u = \([I⊗ldirichlet(dt); ldirichlet(dx)⊗I; Dt+Dx], [u0; 0; 0];
            tolerance=1E-3)
plot(u)
# Out:
#   2.461643 seconds (8.88 M allocations: 677.165 MiB, 17.02% gc time)

# %% [markdown]
# ## Piecewise PDE $$u_t+\begin{cases} 0.5 & 0≤x≤0.5\cr                     1 & \hbox{otherwise}\end{cases} u_{xx}$$

# %% [markdown]
# We can solve on piecewise domains. Here is convection with two different speeds, imposing continuity at the singularities.

# %%
 -1.0 .. 0.0 ∪ 0.0 .. 0.5 ∪ 0.5 .. 1.0
# Out:
# syntax: extra token ".." after end of expression

# %%
a = Fun(x -> 0 ≤ x ≤ 0.5 ? 0.5 : 1, Chebyshev(-1.0 .. 0.0) ∪ Chebyshev(0.0 .. 0.5) ∪ Chebyshev(0.5 .. 1.0))
s = space(a)
dt = 0.0 .. 2.0
Dx = Derivative(s); Dt=Derivative(dt)
Bx = [ldirichlet(s);continuity(s,0)]
@time u = \([I⊗ldirichlet(dt);Bx⊗I;I⊗Dt+(a*Dx)⊗I],
    [Fun(x->exp(-20(x+0.5)^2),s),[0,[0,0]],0.0];tolerance=1E-3)

plot(u)
# Out:
#  50.178333 seconds (259.20 M allocations: 12.768 GiB, 13.19% gc time)

# %% [markdown]
# # Convection $u_t - x u_x = 0, u(x,0)=e^{-20x^2}, u(-1,t)=u(1,t)=0$

# %%
dx = (-1.0 .. 1.0); dt = (0.0 .. 2.0)
d=dx*dt
Dx=Derivative(d,[1,0]); Dt=Derivative(d,[0,1])
x,t=Fun(identity,d)

#timedirichlet is [u(x,0), u(-1,t), u(1,t)]
u0 = Fun(x->exp(-20x^2),dx)
@time u=\([timedirichlet(d);Dt-x*Dx],[u0,[0,0],0];tolerance=1E-3)
plot(u)
# Out:
#  38.029761 seconds (411.09 M allocations: 24.743 GiB, 35.84% gc time)
# <script src="file:///Users/solver/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="a7928a3e-d425-4de1-9c19-3573e03f2a27" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('a7928a3e-d425-4de1-9c19-3573e03f2a27');
#     Plotly.plot(PLOT, [{"xaxis":"x","colorbar":{"title":""},"colorscale":[[0.0,"rgba(0, 0, 4, 1.000)"],[0.034482758620689655,"rgba(4, 3, 20, 1.000)"],[0.06896551724137931,"rgba(13, 8, 41, 1.000)"],[0.10344827586206896,"rgba(24, 12, 60, 1.000)"],[0.13793103448275862,"rgba(38, 12, 81, 1.000)"],[0.1724137931034483,"rgba(54, 9, 97, 1.000)"],[0.20689655172413793,"rgba(69, 10, 105, 1.000)"],[0.2413793103448276,"rgba(84, 15, 109, 1.000)"],[0.27586206896551724,"rgba(97, 19, 110, 1.000)"],[0.3103448275862069,"rgba(111, 25, 110, 1.000)"],[0.3448275862068966,"rgba(125, 30, 109, 1.000)"],[0.3793103448275862,"rgba(140, 35, 105, 1.000)"],[0.41379310344827586,"rgba(154, 40, 101, 1.000)"],[0.4482758620689655,"rgba(166, 45, 96, 1.000)"],[0.4827586206896552,"rgba(180, 51, 89, 1.000)"],[0.5172413793103449,"rgba(193, 58, 80, 1.000)"],[0.5517241379310345,"rgba(206, 67, 71, 1.000)"],[0.5862068965517241,"rgba(216, 76, 62, 1.000)"],[0.6206896551724138,"rgba(226, 87, 52, 1.000)"],[0.6551724137931034,"rgba(235, 100, 41, 1.000)"],[0.6896551724137931,"rgba(241, 115, 29, 1.000)"],[0.7241379310344828,"rgba(247, 130, 18, 1.000)"],[0.7586206896551724,"rgba(250, 144, 8, 1.000)"],[0.7931034482758621,"rgba(252, 161, 8, 1.000)"],[0.8275862068965517,"rgba(252, 178, 22, 1.000)"],[0.8620689655172413,"rgba(250, 196, 42, 1.000)"],[0.896551724137
.0055248072559062385,0.01985242285535206,0.061927946545847344,0.1632884150778648,0.3557544845975691,0.628846384122417,0.8898960656219024,0.9999999905136431,0.8898960656219024,0.6288463841224168,0.355754484597569,0.1632884150778648,0.06192794654584705,0.01985242285535227,0.005524807255906574,0.0013753587225236005,0.00031642756108140815,6.963134307917408e-5,1.5190891555279475e-5,3.401819322736174e-6,8.118064708031164e-7,2.1064947481596065e-7,6.449036574186414e-8,2.1557930671473932e-8,9.53048161781906e-9,4.708350087651119e-9,3.068722225179325e-9,2.2280441100857348e-9],[4.8418474635063934e-9,6.423049307504005e-9,7.867959131913402e-9,1.8971773589037025e-8,3.997831596065463e-8,1.1661426486690682e-7,3.7286399217538674e-7,1.3559543043152636e-6,5.381965771124534e-6,2.2769305150231647e-5,9.874510088538089e-5,0.00042458458777976744,0.0017491491060114912,0.006678725383253294,0.022904524162340782,0.06854363822190448,0.17445054882657102,0.3694261033425813,0.6395803160369624,0.89369173803912,1.00000000128522,0.89369173803912,0.6395803160369622,0.3694261033425812,0.17445054882657102,0.06854363822190422,0.02290452416234099,0.006678725383253607,0.0017491491060115509,0.00042458458777942934,9.874510088526449e-5,2.2769305150174137e-5,5.381965770916381e-6,1.355954304365674e-6,3.72863992409214e-7,1.1661426490523252e-7,3.997831578969543e-8,1.8971773524873855e-8,7.867 ...

# %% [markdown]
# # Convection diffusion $u_t = \epsilon u_{xx} + (2+x) u_x, u(x,0)=e^{-20x^2}, u(-1,t)=u(1,t) = 0$

# %%
dx = (-1.0 .. 1.0); dt = (0.0..1.0)
d = dx × dt
ε = 0.01
Dx = Derivative(d,[1,0]); Dt = Derivative(d,[0,1])
x,t = Fun(d)
V = 2.0+x
u0 = Fun(x->exp(-20x^2),dx)
@time u = \([timedirichlet(d);Dt-ε*Dx^2-V*Dx],[u0,[0,0],0];
                    tolerance=1E-6)

contourf(u)
# Out:
#   2.741231 seconds (13.46 M allocations: 1.008 GiB, 23.39% gc time)

# %% [markdown]
# # Wave equation with left Dirichlet and right Neumann $u_{tt} = u_{xx}, u(x,0)=e^{-20(x-.1)^2},u_t(x,0)=0,u(-1,t)=0,u_x(1,t)=0$

# %%
dx=Domain(-1..1);dt=Domain(0..4)
d=dx*dt
Dx=Derivative(d,[1,0]);Dt=Derivative(d,[0,1])
# need to specify both ic and its derivative
B=[I⊗ldirichlet(dt),I⊗lneumann(dt),ldirichlet(dx)⊗I,rneumann(dx)⊗I]

u0=Fun(x->exp(-20(x-.1)^2),dx)
@time u=\([B;Dt^2-Dx^2],[u0;0;0;0;0];
                    tolerance=1E-4)

plot(u)
# Out:
#   6.987815 seconds (39.63 M allocations: 1.870 GiB, 13.69% gc time)
# <script src="file:///Users/solver/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="fea8ef53-6e75-46c9-8466-82f17bc7b9b2" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById
278426433554e-6,5.570088182263455e-6,1.8656393072630575e-5,6.152829389200008e-5,0.00019902616387611465,0.000620315165184632,0.0018426240694090676,0.005155546219966918,0.013449399668247545,0.03241482272955485,0.07158735009153393,0.14382438539196268,0.26125315420037953,0.42693035329511464,0.6252894446276459,0.8187269436106753,0.9571734147658227,0.9992002684201419,0.9326025101464016,0.7802620955403932,0.5874002984761467,0.39988783608618705,0.24768383630430596,0.14057515314622987,0.07370239544167378,0.03601616289610797,0.016564033110775995,0.007244043595662129,0.0030458166845052093,0.0012451227631794168,0.0005005049106128409,0.00019994508494683427,8.027680386583046e-5,3.269741379996298e-5,1.381037121599496e-5,6.126799076987266e-6,3.1135888614516882e-6,1.8234023979324387e-6,1.042392798092373e-6,4.0251052578488267e-7,1.2136304267107434e-8,-3.151749090879452e-8,3.344468423455149e-7,6.349383734338687e-7,5.850701686599402e-7],[-1.529248258961855e-5,-0.000101577738789261 ...

# %% [markdown]
# # Linear KdV Dirichlet $u_t + u_{xxx} = 0, u(x,0)=e^{-10x^2},u(-1,t)=u(1,t)=u_x(1,t)=0$

# %%
dx=Domain(-5..1);dt=Domain(0..0.1)
d=dx*dt
Dx=Derivative(d,[1,0]);Dt=Derivative(d,[0,1])
B=[timedirichlet(d);rneumann(dx)⊗I]
u0=Fun(x->exp(-10x^2),dx)
@time u=\([B;Dt+Dx^3],[u0,[0,0],0,0];tolerance=1E-3)

plot(u)
# Out:
#  49.882609 seconds (332.54 M allocations: 19.412 GiB, 14.56% gc time)
# <script src="file:///Users/solver/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="21a9c944-bff1-4417-9105-b41a9ba1ebe9" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('21a9c944-bff1-4417-9105-b41a9ba1ebe9');
#     Plotly.plot(PLOT, [{"xaxis":"x","colorbar":{"title":""},"colorscale":[[0.0,"rgba(0, 0, 4, 1.000)"],[0.034482758620689655,"rgba(4, 3, 20, 1.000)"],[0.06896551724137931,"rgba(13, 8, 41, 1.000)"],[0.10344827586206896,"rgba(24, 12, 60, 1.000)"],[0.13793103448275862,"rgba(38, 12, 81, 1.000)"],[0.1724137931034483,"rgba(54, 9, 97, 1.000)"],[0.20689655172413793,"rgba(69, 10, 105, 1.000)"],[0.2413793103448276,"rgba(84, 15, 109, 1.000)"],[0.27586206896551724,"rgba(97, 19, 110, 1.000)"],[0.3103448275862069,"rgba(111, 25, 110, 1.000)"],[0.3448275862068966,"rgba(125, 30, 109, 1.000)"],[0.3793103448275862,"rgba(140, 35, 105, 1.000)"],[0.41379310344827586,"rgba(154, 40, 101, 1.000)"],[0.4482758620689655,"rgba(166, 45, 96, 1.000)"],[0.4827586206896552,"rgba(180, 51, 89, 1.000)"],[0.5172413793103449,"rgba(193, 58, 80, 1.000)"],[0.5517241379310345,"rgba(206, 67, 71, 1.000)"],[0.5862068965517241,"rgba(216, 76, 62, 1.000)"],[0.6206896551724138,"rgba(226, 87, 52, 1.000)"],[0.6551724137931034,"rgba(235, 100, 41, 1.000)"],[0.6896551724137931,"rgba(241, 115, 29, 1.000)"],[0.7241379310344828,"rgba(247, 130, 18, 1.000)"],[0.7586206896551724,"rgba(250, 144, 8,
183,-4.1908120398438715,-4.15139541427689,-4.111198888610901,-4.070237034446336,-4.028524700822058,-3.9860770088324555,-3.942909346145906,-3.899037361426611,-3.8544769586618157,-3.8092442913964684,-3.763355756877419,-3.7168279901092687,-3.6696778578240314,-3.6219224523667926,-3.573579085499583,-3.5246652821257074,-3.4751987739368113,-3.425197492984984,-3.3746795651822312,-3.323663303729664,-3.2721672024788053,-3.2202099292274005,-3.1678103189521742,-3.1149873669809827,-3.0617602221068356,-3.00814817964629,-2.9541706744447245,-2.899847273831032,-2.845197670524289,-2.79024167549497,-2.734999210783291,-2.6794903022772933,-2.623735072453278,-2.5677537330812306,-2.511566577897871,-2.455193975249995,-2.398656360710762,-2.3419742296716217,-2.285168129912548,-2.228258654153285,-2.171266432588304,-2.11421212540817,-2.05711641531004,-2.0,-1.94288358468996,-1.8857878745918302,-1.828733567411696,-1.7717413458467148,-1.714831870087452,-1.6580257703283783,-1.601343639289238,-1.544806024750005,-1.4884334221021287,-1.4322462669187694,-1.376264927546722,-1.3205096977227069,-1.265000789216709,-1.2097583245050298,-1.1548023294757108,-1.100152726168968,-1.0458293255552753,-0.9918518203537097,-0.9382397778931644,-0.8850126330190173,-0.8321896810478258,-0.7797900707725993,-0.7278327975211947,-0.6763366962703361,-0.6253204348177688,-0.5748025070150156,-0.5248012260631887,-0.4753347178742926,-0.42642091450041697,-0.37807754763320744,-0.3303221421759688,-0.2831720098907313,-0.2366442431225806,-0.19075570860353164,-0.1455230413381845,-0.10096263857338883,-0.057090653854094064,-0.013922991167544474,0.028524700822058158,0.07023703444633611,0.11119888861090121,0.15139541427689007,0.19081203984387196,0.22943447643218295,0.26724872 ...

# %% [markdown]
# # Beam equation $u_{tt} + u_{xxxx} = 0, u(x,0)=e^{-200(x-1/2)^2}, u_t(x,0)=u(\pm,t)=u_x(\pm 1,t) = 0$

# %%
dx = (0.0..1); dt = (0..0.03)
d = dx × dt
Dx=Derivative(d,[1,0]); Dt=Derivative(d,[0,1]);
x,t=Fun(d)

u0 = Fun(x->exp(-200(x-.5)^2),dx)

@time u = \(
    [timedirichlet(d); I ⊗ lneumann(dt); Neumann(dx) ⊗ I; Dt^2+Dx^4],
    [u0,[0,0],0,[0,0],0]; tolerance=1E-4)

plot(u)

# %% [markdown]
# # Biharmonic equation $\Delta^2 u = f(x,y)$

# %%
S=WeightedJacobi(2.,2.)^2

Δ=Laplacian(S)

@time f=chop(Fun((x,y)->exp(-30(x^2+y^2)),rangespace(Δ^2)),1E-10)
@time u=\(Δ^2,f;tolerance=1E-8)
plot(u)
# Out:
#   1.222698 seconds (4.82 M allocations: 1.168 GiB, 28.75% gc time)
#   7.113051 seconds (116.66 M allocations: 6.699 GiB, 36.34% gc time)
# <script src="file:///Users/solver/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="cafa7c0d-6964-4a53-bc08-d60101400edb" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById
e-6,5.310578623546722e-7,5.0515468139563074e-8,-4.464899762673578e-8,-1.4904025146529223e-8],[-1.0095904000000196e-8,5.0497404308923784e-8,6.114490149432805e-7,2.4345643527977253e-6,6.27258303958311e-6,1.251900623465628e-5,2.1040051405436675e-5,3.115263744278972e-5,4.167524730492565e-5,5.104278311094488e-5,5.7575334801616135e-5,5.992652444078181e-5,5.7575334801616135e-5,5.1042783110944876e-5,4.167524730492565e-5,3.115263744278973e-5,2.1040051405436682e-5,1.251900623465628e-5,6.272583039583109e-6,2.4345643527977253e-6,6.114490149432798e-7,5.049740430892384e-8,-1.0095904000000092e-8],[5.3897408749515567e-8,5.310903241546818e-7,2.4345510843753474e-6,7.358311813343339e-6,1.6912970311532596e-5,3.200521257880911e-5,5.2379277651346794e-5,7.648481117106473e-5,0.00010155088450724973,0.00012386854445540634,0.00013943396059589282,0.00014503693065728455,0.00013943396059589282,0.00012386854445540636,0.00010155088450724973,7.648481117106475e-5,5.23792776513468e-5,3.200521257880911e-5,1.6912970311532596e-5,7.358311813343341e-6,2.4345510843753465e-6,5.310903241546814e-7,5.3897408749 ...

# %% [markdown]
# # Schrödinger Dirichlet $i \epsilon u_t + .5 \epsilon^2 u_{xx} = x^2 u, u(x,0)=e^{-25(x-.5)^2}e^{-i/(5ϵ)log(2cosh(5(x-.5)))}$

# %%
dx=Domain(0..1);dt=Domain(0..0.54)
d=dx*dt

ϵ=0.0256
u0=Fun(x->exp(-25*(x-.5)^2)*exp(-1.0im/(5*ϵ)*log(2cosh(5*(x-.5)))),dx)

x,t=Fun(d)
V=x^2

Dt=Derivative(d,[0,1]);Dx=Derivative(d,[1,0])

L=1im*ϵ*Dt+.5*ϵ^2*Dx^2-V

@time u=\([timedirichlet(d);L],[u0,[0,0],0];tolerance=1E-2)

plot(real(u))
# Out:
#  10.940964 seconds (91.36 M allocations: 5.774 GiB, 27.15% gc time)
# <script src="file:///Users/solver/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="640ca377-13d9-409c-8619-8975696a1a91" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('640ca377-13d9-409c-8619-8975696a1a91');
#     Plotly.plot(PLOT, [{"xaxis":"x","colorbar":{"title":""},"colorscale":[[0.0,"rgba(0, 0, 4, 1.000)"],[0.034482758620689655,"rgba(4, 3, 20, 1.000)"],[0.06896551724137931,"rgba(13, 8, 41, 1.000)"],[0.10344827586206896,"rgba(24, 12, 60, 1.000)"],[0.13793103448275862,"rgba(38, 12, 81, 1.000)"],[0.1724137931034483,"rgba(54, 9, 97, 1.000)"],[0.20689655172413793,"rgba(69, 10, 105, 1.000)"],[0.2413793103448276,"rgba(84, 15, 109, 1.000)"],[0.27586206896551724,"rgba(97, 19, 110, 1.000)"],[0.3103448275862069,"rgba(111, 25, 110, 1.000)"],[0.3448275862068966,"rgba(125, 30, 109, 1.000)"],[0.3793103448275862,"rgba(140, 35, 105, 1.000)"],[0.41379310344827586,"rgba(154, 40, 101, 1.000)"],[0.4482758620689655,"rgba(166, 45, 96, 1.000)"],[0.4827586206896552,"rgba(180, 51, 89, 1.000)"],[0.5172413793103449,"rgba(193, 58, 80, 1.000)"],[0.5517241379310345,"rgba(206